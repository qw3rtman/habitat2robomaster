# %%
from PIL import Image, ImageDraw, ImageFont
from habitat_dataset import HabitatDataset
import numpy as np

# %%
d = HabitatDataset('test/train/000001')
rgb = np.uint8(d[0][0])

# %%
frame = Image.fromarray(rgb)
draw = ImageDraw.Draw(frame)
# font = ImageFont.truetype('/usr/share/fonts/truetype/noto/NotoMono-Regular.ttf', 18)
font = ImageFont.truetype('/Users/nimit/Library/Fonts/OpenSans-Regular.ttf', 18)
draw.rectangle((0, 0, 255, 20), fill='black')
draw.text((0, 0), '({: <5.1f}, {: <5.1f}) {: <4.1f}'.format(5.3, -4.6, 20.7), fill='white', font=font)
frame
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x13B299190>

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt
x = np.arange(0, 61)
y = [236601344, 409776640, 582426112, 754551296, 926676480, 1098801664, 1270926848, 1443052032, 1615177216, 1787302400, 1959427584, 2131552768, 2303677952, 2475803136, 2647928320, 2820053504, 2992178688, 3164303872, 3336429056, 3508554240, 3680679424, 3852804608, 4024929792, 4197054976, 4369180160, 4541305344, 4713430528, 4885555712, 5057680896, 5229806080, 5401931264, 5574056448, 5746181632, 5918306816, 6090432000, 6262557184, 6434682368, 6606807552, 6778932736, 6951057920, 7123183104, 7295308288, 7467433472, 7639558656, 7811683840, 7983809024, 8155934208, 8328059392, 8500184576, 8672309760, 8844434944, 9016560128, 9188685312, 9360810496, 9532935680, 9705060864, 9877186048, 10049311232, 10221436416, 10393561600, 10565686784]

plt.plot(x, y)

# %% [markdown]
# ---

# %%
sequence_length_capacity = 40
length = 129
for start in range(0, length, sequence_length_capacity):
    end = min(start+sequence_length_capacity, length)
    print(f'{start}:{end}')
# Out:
# 0:40
# 40:80
# 80:120
# 120:129
